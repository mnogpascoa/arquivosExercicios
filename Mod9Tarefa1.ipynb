# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv('SINASC_RO_2019.csv')
sinasc_raw.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %% [markdown]
# # Tarefa 1

# %% [markdown]
# ### 1. Idade media das mães e dos pais por município (coluna munResNome)

# %%
df = sinasc_raw[['IDADEMAE','IDADEPAI','munResNome']]
df = df.groupby('munResNome').agg({'IDADEMAE': 'mean', 'IDADEPAI': 'mean'}).reset_index()
df.head()
# Out:
#                 munResNome   IDADEMAE   IDADEPAI
# 0    Alta Floresta D'Oeste  25.991826  29.548701
# 1  Alto Alegre dos Parecis  24.844156  29.179104
# 2             Alto Paraíso  24.960177  28.833333
# 3         Alvorada D'Oeste  25.770732  30.757282
# 4                Ariquemes  25.607866  32.466667

# %% [markdown]
# ### 2. Peso médio dos bebes por sexo que nasceram no dia do seu aniversário por faixas de escolaridade mae
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
df2 = sinasc_raw[['PESO','SEXO','DTNASC','ESCMAE']]
df2 = df2[df2['DTNASC'] == '2019-11-18']
df2
# Out:
#        PESO       SEXO      DTNASC           ESCMAE
# 13815  3352  Masculino  2019-11-18       4 a 7 anos
# 14766  3130   Feminino  2019-11-18      8 a 11 anos
# 14815  3536  Masculino  2019-11-18      8 a 11 anos
# 14816  3840  Masculino  2019-11-18       4 a 7 anos
# 14817  3430  Masculino  2019-11-18      8 a 11 anos
# ...     ...        ...         ...              ...
# 26449  3170   Feminino  2019-11-18      8 a 11 anos
# 26450  1880  Masculino  2019-11-18      8 a 11 anos
# 26451  3810  Masculino  2019-11-18      8 a 11 anos
# 26456  3555  Masculino  2019-11-18  12 anos ou mais
# 26743  2760  Masculino  2019-11-18      8 a 11 anos
#
# [90 rows x 4 columns]

# %%
df2 = df2.groupby(['ESCMAE','SEXO']).agg({'PESO': 'mean'}).reset_index()
df2
# Out:
#             ESCMAE       SEXO         PESO
# 0       1 a 3 anos  Masculino  3530.000000
# 1  12 anos ou mais   Feminino  3326.666667
# 2  12 anos ou mais  Masculino  3334.000000
# 3       4 a 7 anos   Feminino  3566.666667
# 4       4 a 7 anos  Masculino  3279.777778
# 5      8 a 11 anos   Feminino  3120.250000
# 6      8 a 11 anos  Masculino  3221.156250

# %% [markdown]
# ### 3. Qual o municipio que nasceu menos bebe em 2019?
#     - qual a idade media, maxima, minima das maes nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
print(f'Município que menos nasceu bebe:')
sinasc_raw['munResNome'].value_counts()
# Out:
# Município que menos nasceu bebe:
# munResNome
# Porto Velho                  8437
# Ji-Paraná                    2182
# Ariquemes                    1729
# Vilhena                      1590
# Cacoal                       1374
# Rolim de Moura                927
# Jaru                          881
# Guajará-Mirim                 781
# Ouro Preto do Oeste           631
# Pimenta Bueno                 616
# Buritis                       583
# Machadinho D'Oeste            500
# Espigão D'Oeste               450
# Nova Mamoré                   432
# Alta Floresta D'Oeste         367
# São Miguel do Guaporé         353
# Candeias do Jamari            337
# Presidente Médici             304
# São Francisco do Guaporé      303
# Nova Brasilândia D'Oeste      261
# Cerejeiras                    237
# Costa Marques                 233
# Alto Paraíso                  226
# Colorado do Oeste             214
# Alvorada D'Oeste              205
# Cujubim                       205
# ...

# %%
df3 = sinasc_raw[['IDADEMAE','IDADEPAI','munResNome']]
df3 = df3[df3['munResNome'] == 'Castanheiras']
df3.head()
# Out:
#       IDADEMAE  IDADEPAI    munResNome
# 2067        18      17.0  Castanheiras
# 2300        31      36.0  Castanheiras
# 4512        22       NaN  Castanheiras
# 5881        26      24.0  Castanheiras
# 5952        32      29.0  Castanheiras

# %%
df3 = df3.agg({'IDADEMAE': ['mean', 'max', 'min'], 'IDADEPAI': ['mean', 'max', 'min']})
df3
# Out:
#        IDADEMAE   IDADEPAI
# mean  27.760417  30.130952
# max   39.000000  43.000000
# min   17.000000  17.000000

# %% [markdown]
# ### 4. Qual o municipio que nasceu mais bebe no mês de março?
#     - qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
df4 = sinasc_raw[['IDADEPAI','QTDFILVIVO','munResNome','DTNASC']]

df4['DTNASC'] = pd.to_datetime(df4['DTNASC'])
df4 = df4[df4['DTNASC'].dt.month == 3]

print(f"Bebês que mais nasceram no mês de Março: {df4['munResNome'].value_counts().idxmax()}")
# Out:
# Bebês que mais nasceram no mês de Março: Porto Velho
# C:\Users\mateu\AppData\Local\Temp\ipykernel_16552\1698197062.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['DTNASC'] = pd.to_datetime(df4['DTNASC'])

# %%
df4 = df4.agg({'QTDFILVIVO': ['mean', 'max', 'min'], 'IDADEPAI': ['mean', 'max', 'min']})
df4
# Out:
#       QTDFILVIVO   IDADEPAI
# mean    1.095009  31.172414
# max     9.000000  62.000000
# min     0.000000  16.000000

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados. Algo que você julgue relevante e novo pra você.

# %% [markdown]
# Em todas as categoria analisadas, seja por município ou escolaridade da mãe, a média de idade dos pais sempre é maior que a das mães.

# %% [markdown]
# Exemplo:
# - Ah, descobri que a idade mediana das mulheres que deram a luz no ano de 2019 dos municipios x é maior que y.

# %%
sinasc_raw.dtypes
# Out:
# ORIGEM          int64
# CODESTAB      float64
# CODMUNNASC      int64
# LOCNASC         int64
# IDADEMAE        int64
#                ...
# munResUf       object
# munResLat     float64
# munResLon     float64
# munResAlt     float64
# munResArea    float64
# Length: 69, dtype: object

# %%
sinasc_raw.select_dtypes(exclude=['int64','float64'])
# Out:
#                 ESCMAE         GESTACAO GRAVIDEZ    PARTO      DTNASC  \
# 0          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-19
# 1          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-21
# 2          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-25
# 3      12 anos ou mais  37 a 41 semanas    Única  Cesáreo  2019-03-20
# 4          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-03-23
# ...                ...              ...      ...      ...         ...
# 27023  12 anos ou mais  32 a 36 semanas    Única  Cesáreo  2019-12-13
# 27024      8 a 11 anos  37 a 41 semanas    Única  Vaginal  2019-10-04
# 27025      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-08-02
# 27026      8 a 11 anos  32 a 36 semanas    Única  Vaginal  2019-12-23
# 27027      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-12-27
#
#             SEXO RACACOR  DTCADASTRO CODANOMAL VERSAOSIST   DTRECEBIM  \
# ...

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
# ...
